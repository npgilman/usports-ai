# %% [markdown]
# <a href="https://colab.research.google.com/github/npgilman/usports-ai/blob/main/usports_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dftrain = pd.read_csv("https://raw.githubusercontent.com/npgilman/usports-ai/main/cfb19.csv")
dfeval = pd.read_csv("https://raw.githubusercontent.com/npgilman/usports-ai/main/cfb20.csv")

#y = dftrain.pop('Team')

dftrain.head()
# Out:
#                          Team  ...  Avg.Turnover.Margin.per.Game
# 0   Air Force (Mountain West)  ...                         -0.15
# 1                 Akron (MAC)  ...                         -1.25
# 2               Alabama (SEC)  ...                          1.38
# 3  Appalachian St. (Sun Belt)  ...                          1.07
# 4            Arizona (Pac-12)  ...                         -0.25
#
# [5 rows x 152 columns]

# %%
ucf_index = np.where(y == 'UCF (AAC)')[0][0]
uf_index = np.where(y == 'Florida (SEC)')[0][0]
fsu_index = np.where(y == 'Florida St. (ACC)')[0][0]

print(ucf_index,uf_index,fsu_index)
# Out:
# 111 30 31

# %%
print(dftrain.loc[[ucf_index]])
print(dftrain.loc[[uf_index]])
print(dftrain.loc[[fsu_index]])
# Out:
#      Games  Win  ...  Turnover.Margin  Avg.Turnover.Margin.per.Game
# 111     13   10  ...                6                          0.46
#
# [1 rows x 151 columns]
#     Games  Win  ...  Turnover.Margin  Avg.Turnover.Margin.per.Game
# 30     13   11  ...                5                          0.38
#
# [1 rows x 151 columns]
#     Games  Win  ...  Turnover.Margin  Avg.Turnover.Margin.per.Game
# 31     13    6  ...               -3                         -0.23
#
# [1 rows x 151 columns]

# %%
dftrain.sort_values('Turnover.Margin',ascending=False).head(10)
# Out:
#                              Team  ...  Avg.Turnover.Margin.per.Game
# 29          Fla. Atlantic (C-USA)  ...                          1.50
# 89  San Diego St. (Mountain West)  ...                          1.46
# 2                   Alabama (SEC)  ...                          1.38
# 75   Notre Dame (FBS Independent)  ...                          1.31
# 82                Oregon (Pac-12)  ...                          1.14
# 3      Appalachian St. (Sun Belt)  ...                          1.07
# 21                  Clemson (ACC)  ...                          1.00
# 5            Arizona St. (Pac-12)  ...                          1.08
# 11                Baylor (Big 12)  ...                          0.79
# 39             Illinois (Big Ten)  ...                          0.77
#
# [10 rows x 152 columns]
